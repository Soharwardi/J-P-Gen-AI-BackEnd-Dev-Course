# %%
# # create a text file and add the below content without quotation marsk
# """
# Hi *user*!

# We've found the best article for you based on your interest: *title*
# Please click *here* to open the article
# """

# Open a file in write mode
with open("invitation.txt", "w") as file:
    # Write the content to the file
    file.write("""Hi *user*!\n\nWe've found the best article for you based on your interest: *title*\nPlease click *here* to open the article""")

# %%
# task is to read the above file and update the placeholder i.e *user*, *title* and *here*
# and store the updated content in user_email.txt
# run program three times with different name, title and link
# after running the program three times
# the file user_email.txt must have all three users content

def update_content(user, title, link):
    # Read the content from the original file
    with open("invitation.txt", "r") as file:
        content = file.read()

    # Replace the placeholders with the actual values
    updated_content = content.replace("*user*", user)
    updated_content = updated_content.replace("*title*", title)
    updated_content = updated_content.replace("*here*", link)

    # Append the updated content to the new file
    with open("user_email.txt", "a") as file:
        file.write(updated_content + "\n\n")  # Add some spacing between each entry

# Run the program three times with different data
update_content("Alice", "How to Learn Python", "https://example.com/python-guide")
update_content("Bob", "Mastering Data Science", "https://example.com/data-science")
update_content("Charlie", "Top 10 JavaScript Tips", "https://example.com/js-tips")

# %%
# Create a new text file named "student_records.txt" with the following initial content:
# Student ID | Student Name | Grade
# 101       | Alice        | A
# 102       | Bob          | B
# 103       | Carol        | C

# Open the "student_records.txt" file in read mode ('r') and read its contents line by line. Print each line to the console.

# Create a new text file named "updated_records.txt" in write mode('w').
# Read the content of "student_records.txt" again and write only the lines containing students with grades 'A' or 'B' 
# to the "updated_records.txt" file.
# Close both files.

# Open "updated_records.txt" in append mode('a') and add a new student record:
# Close the "updated_records.txt" file.

# Open "updated_records.txt" in read mode and print its contents to the console to verify that the new student
# record has been added.



# Step 1: Create the initial student_records.txt file with the given content
with open("student_records.txt", "w") as file:
    file.write("Student ID | Student Name | Grade\n")
    file.write("101       | Alice        | A\n")
    file.write("102       | Bob          | B\n")
    file.write("103       | Carol        | C\n")

# Step 2: Open "student_records.txt" in read mode and print its contents line by line
with open("student_records.txt", "r") as file:
    for line in file:
        print(line.strip())

# Step 3: Create "updated_records.txt" and write only lines with grades 'A' or 'B'
with open("student_records.txt", "r") as file:
    lines = file.readlines()

with open("updated_records.txt", "w") as file:
    for line in lines:
        # Split the line by '|' and check the third part for the grade
        parts = line.split('|')
        if len(parts) == 3 and parts[2].strip() in ['A', 'B']:
            file.write(line)

# Step 4: Open "updated_records.txt" in append mode and add a new student record
with open("updated_records.txt", "a") as file:
    file.write("104       | David        | A\n")

# Step 5: Open "updated_records.txt" in read mode and print its contents
with open("updated_records.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Student ID | Student Name | Grade
# 101       | Alice        | A
# 102       | Bob          | B
# 103       | Carol        | C
# 101       | Alice        | A
# 102       | Bob          | B
# 104       | David        | A

# %%
### Assignment: Password Manager Program
# Demo: https://www.youtube.com/watch?v=O8596GPSJV4

# #### Objective:
# Create a password manager program that allows users to store, retrieve, and manage their passwords. 
# The program will use file handling to save and read data, and it will be run in the terminal.

# #### Requirements:
# 1. **File Handling**: Store the passwords in a file. Each entry should include the website, username, and password.
# 2. **Input Function**: Allow users to add new passwords, retrieve existing passwords, and delete passwords.
# 3. **Basic Operations**:
#     - **Add a new password**: Ask for the website, username, and password. Save this information to the file.
#     - **Retrieve a password**: Ask for the website and return the username and password.
#     - **Delete a password**: Ask for the website and remove the corresponding entry from the file.
# 4. **Basic Error Handling**: Handle cases where the website is not found when retrieving or deleting a password and also
# when file doesn't exists


import os

# Function to display the menu
def display_menu():
    print("\nPassword Manager")
    print("1. Add a new password")
    print("2. Retrieve a password")
    print("3. Delete a password")
    print("4. Exit")

# Function to add a new password
def add_password():
    website = input("Enter the website: ")
    username = input("Enter the username: ")
    password = input("Enter the password: ")

    with open("passwords.txt", "a") as file:
        file.write(website + " | " + username + " | " + password + "\n")
    
    print("Password added successfully!")

# Function to retrieve a password
def retrieve_password():
    website = input("Enter the website to retrieve: ")

    if not os.path.exists("passwords.txt"):
        print("No passwords stored yet!")
        return

    with open("passwords.txt", "r") as file:
        found = False
        for line in file:
            if line.startswith(website):
                found = True
                data = line.strip().split(" | ")
                print(f"Website: {data[0]}\nUsername: {data[1]}\nPassword: {data[2]}")
                break

        if not found:
            print("Website not found!")

# Function to delete a password
def delete_password():
    website = input("Enter the website to delete: ")

    if not os.path.exists("passwords.txt"):
        print("No passwords stored yet!")
        return

    with open("passwords.txt", "r") as file:
        lines = file.readlines()

    with open("passwords.txt", "w") as file:
        found = False
        for line in lines:
            if line.startswith(website):
                found = True
                print(f"Deleted password for {website}")
                continue
            file.write(line)

        if not found:
            print("Website not found!")

# Main loop to run the program
while True:
    display_menu()
    choice = input("Enter your choice: ")

    if choice == "1":
        add_password()
    elif choice == "2":
        retrieve_password()
    elif choice == "3":
        delete_password()
    elif choice == "4":
        print("Exiting Password Manager...")
        break
    else:
        print("Invalid choice! Please select a valid option.")
# Out:
# Password Manager
# 1. Add a new password
# 2. Retrieve a password
# 3. Delete a password
# 4. Exit
# Enter your choice: 123
# Invalid choice! Please select a valid option.
#
# Password Manager
# 1. Add a new password
# 2. Retrieve a password
# 3. Delete a password
# 4. Exit
# Enter your choice: 123
# Invalid choice! Please select a valid option.
#
# Password Manager
# 1. Add a new password
# 2. Retrieve a password
# 3. Delete a password
# 4. Exit
# Enter your choice: 4
# Exiting Password Manager...

# %%
# #### Program Flow:
# 1. Display a menu with the following options:
#     - Add a new password
#     - Retrieve a password
#     - Delete a password
#     - Exit
# 2. Based on the user's choice, perform the corresponding operation.
# 3. Repeat the menu until the user chooses to exit.

# #### Detailed Instructions:
# 1. **Menu Display**: Create a function to display the menu and get the user's choice.
# 2. **Add Password**:
#     - Prompt the user for the website, username, and password.
#     - Write this information to a file in a structured format.
# 3. **Retrieve Password**:
#     - Prompt the user for the website.
#     - Read the file and find the entry for the given website.
#     - Display the username and password.
# 4. **Delete Password**:
#     - Prompt the user for the website.
#     - Read the file and find the entry for the given website.
#     - Remove the entry and update the file.
# 5. **File Format**: Store each entry in a new line in the format:
#     ```
#     website,username,password
#     ```

# #### Example:
# 1. **Add Password**:
#     ```
#     Enter website: example.com
#     Enter username: user1
#     Enter password: pass123
#     Password saved successfully!
#     ```
# 2. **Retrieve Password**:
#     ```
#     Enter website: example.com
#     Username: user1
#     Password: pass123
#     ```
# 3. **Delete Password**:
#     ```
#     Enter website: example.com
#     Password deleted successfully!
#     ```

# #### Hints:
# - Use functions to keep your code organized.
# - Use lists and dictionaries to manage the data in memory before writing to or reading from the file.
# - Ensure to handle cases where the file may not exist initially.

# #### Additional Notes:
# - Focus on functionality rather than security for this assignment.
# """

# """
# create the same program again but this time file data should be stored in json
# """

# """

import json
import os

# Function to display the menu
def display_menu():
    print("\nPassword Manager")
    print("1. Add a new password")
    print("2. Retrieve a password")
    print("3. Delete a password")
    print("4. Exit")

# Function to load data from the JSON file
def load_data():
    if os.path.exists("passwords.json"):
        with open("passwords.json", "r") as file:
            return json.load(file)
    return {}

# Function to save data to the JSON file
def save_data(data):
    with open("passwords.json", "w") as file:
        json.dump(data, file, indent=4)

# Function to add a new password
def add_password():
    website = input("Enter the website: ")
    username = input("Enter the username: ")
    password = input("Enter the password: ")

    data = load_data()
    data[website] = {"username": username, "password": password}
    save_data(data)
    
    print("Password added successfully!")

# Function to retrieve a password
def retrieve_password():
    website = input("Enter the website to retrieve: ")

    data = load_data()
    if website in data:
        print(f"Website: {website}\nUsername: {data[website]['username']}\nPassword: {data[website]['password']}")
    else:
        print("Website not found!")

# Function to delete a password
def delete_password():
    website = input("Enter the website to delete: ")

    data = load_data()
    if website in data:
        del data[website]
        save_data(data)
        print("Password deleted successfully!")
    else:
        print("Website not found!")

# Main loop to run the program
while True:
    display_menu()
    choice = input("Enter your choice: ")

    if choice == "1":
        add_password()
    elif choice == "2":
        retrieve_password()
    elif choice == "3":
        delete_password()
    elif choice == "4":
        print("Exiting Password Manager...")
        break
    else:
        print("Invalid choice! Please select a valid option.")

# %%
# create the same program again but this time file data should be stored in binary using pickle module
# """


# """
# An email with placeholders for user details that need to be formatted.
# An email subject in all lowercase that needs to be converted to uppercase.
# An email body in all uppercase that needs to be converted to lowercase.
# An email with a sentence that needs to have the first letter capitalized.
# An email subject that needs to be converted to title case.
# An email body with leading and trailing spaces that need to be removed.
# An email with a repeated word that needs to be replaced.
# An email that needs to find the position of a keyword.
# An email body that needs to be split into a list of words.
# An email with a list of words that need to be joined into a single sentence.

import pickle
import os

# Function to display the menu
def display_menu():
    print("\nPassword Manager")
    print("1. Add a new password")
    print("2. Retrieve a password")
    print("3. Delete a password")
    print("4. Exit")

# Function to load data from the pickle file
def load_data():
    if os.path.exists("passwords.pkl"):
        with open("passwords.pkl", "rb") as file:
            return pickle.load(file)
    return {}

# Function to save data to the pickle file
def save_data(data):
    with open("passwords.pkl", "wb") as file:
        pickle.dump(data, file)

# Function to add a new password
def add_password():
    website = input("Enter the website: ")
    username = input("Enter the username: ")
    password = input("Enter the password: ")

    data = load_data()
    data[website] = {"username": username, "password": password}
    save_data(data)
    
    print("Password added successfully!")

# Function to retrieve a password
def retrieve_password():
    website = input("Enter the website to retrieve: ")

    data = load_data()
    if website in data:
        print(f"Website: {website}\nUsername: {data[website]['username']}\nPassword: {data[website]['password']}")
    else:
        print("Website not found!")

# Function to delete a password
def delete_password():
    website = input("Enter the website to delete: ")

    data = load_data()
    if website in data:
        del data[website]
        save_data(data)
        print("Password deleted successfully!")
    else:
        print("Website not found!")

# Main loop to run the program
while True:
    display_menu()
    choice = input("Enter your choice: ")

    if choice == "1":
        add_password()
    elif choice == "2":
        retrieve_password()
    elif choice == "3":
        delete_password()
    elif choice == "4":
        print("Exiting Password Manager...")
        break
    else:
        print("Invalid choice! Please select a valid option.")
        
        
        
        
# Email subject in all lowercase that needs to be converted to uppercase
subject = "this is an email subject"
subject_upper = subject.upper()
print("Uppercase Subject:", subject_upper)

# Email body in all uppercase that needs to be converted to lowercase
body_upper = "THIS IS AN EMAIL BODY."
body_lower = body_upper.lower()
print("Lowercase Body:", body_lower)

# Email with a sentence that needs to have the first letter capitalized
sentence = "this is a sentence."
sentence_capitalized = sentence.capitalize()
print("Capitalized Sentence:", sentence_capitalized)

# Email subject that needs to be converted to title case
subject_title = subject.title()
print("Title Case Subject:", subject_title)

# Email body with leading and trailing spaces that need to be removed
body_with_spaces = "   This is an email body with spaces.   "
body_trimmed = body_with_spaces.strip()
print("Trimmed Body:", body_trimmed)

# Email with a repeated word that needs to be replaced
email_with_repeated_word = "This is a test test email."
email_replaced = email_with_repeated_word.replace("test test", "test")
print("Replaced Email:", email_replaced)

# Email that needs to find the position of a keyword
keyword_position = email_with_repeated_word.find("test")
print("Keyword Position:", keyword_position)

# Email body that needs to be split into a list of words
body_to_split = "This is an email body."
words_list = body_to_split.split()
print("List of Words:", words_list)

# Email with a list of words that need to be joined into a single sentence
words_to_join = ["This", "is", "a", "sentence."]
joined_sentence = " ".join(words_to_join)
print("Joined Sentence:", joined_sentence)
# Out:
# Password Manager
# 1. Add a new password
# 2. Retrieve a password
# 3. Delete a password
# 4. Exit
# Enter your choice:
# Invalid choice! Please select a valid option.
#
# Password Manager
# 1. Add a new password
# 2. Retrieve a password
# 3. Delete a password
# 4. Exit

# %%
# emails.txt
# Email 1:
# Hello, {name}! Your account has been {status}.

# Email 2:
# subject: meeting reminder
# body: Don't forget about the meeting tomorrow.

# Email 3:
# subject: IMPORTANT UPDATE
# body: PLEASE REVIEW THE ATTACHED DOCUMENT.

# Email 4:
# subject: follow up
# body: this email needs to be capitalized.

# Email 5:
# subject: weekly update
# body: Here is your weekly update on the project status.

# Email 6:
# subject:  Feedback
# body:    Thank you for your feedback. Please respond at your earliest convenience.    

# Email 7:
# subject: error report
# body: The system encountered an error error that needs to be addressed.

# Email 8:
# subject: keyword search
# body: Please find the keyword 'search' in this email.

# Email 9:
# subject: word split
# body: Split this email into individual words.

# Email 10:
# subject: words join
# body: join these words into a single sentence
# """

# Email data
emails = {
    "Email 1": "Hello, {name}! Your account has been {status}.",
    "Email 2": {
        "subject": "meeting reminder",
        "body": "Don't forget about the meeting tomorrow."
    },
    "Email 3": {
        "subject": "IMPORTANT UPDATE",
        "body": "PLEASE REVIEW THE ATTACHED DOCUMENT."
    },
    "Email 4": {
        "subject": "follow up",
        "body": "this email needs to be capitalized."
    },
    "Email 5": {
        "subject": "weekly update",
        "body": "Here is your weekly update on the project status."
    },
    "Email 6": {
        "subject": "Feedback",
        "body": "    Thank you for your feedback. Please respond at your earliest convenience.    "
    },
    "Email 7": {
        "subject": "error report",
        "body": "The system encountered an error error that needs to be addressed."
    },
    "Email 8": {
        "subject": "keyword search",
        "body": "Please find the keyword 'search' in this email."
    },
    "Email 9": {
        "subject": "word split",
        "body": "Split this email into individual words."
    },
    "Email 10": {
        "subject": "words join",
        "body": "join these words into a single sentence"
    }
}

# Example tasks
# 1. Replace placeholders
formatted_email = emails["Email 1"].format(name="John Doe", status="activated")
print(formatted_email)

# 2. Convert email subject to uppercase
email_subject = emails["Email 2"]["subject"].upper()
print(email_subject)

# 3. Convert email body to lowercase
email_body = emails["Email 3"]["body"].lower()
print(email_body)

# 4. Capitalize the first letter of the email body
email_body_capitalized = emails["Email 4"]["body"].capitalize()
print(email_body_capitalized)

# 5. Convert subject to title case
email_subject_title = emails["Email 5"]["subject"].title()
print(email_subject_title)

# 6. Remove leading and trailing spaces from email body
email_body_trimmed = emails["Email 6"]["body"].strip()
print(email_body_trimmed)

# 7. Replace repeated word in email body
email_body_replaced = emails["Email 7"]["body"].replace("error error", "error")
print(email_body_replaced)

# 8. Find position of a keyword
keyword_position = emails["Email 8"]["body"].find("search")
print(keyword_position)

# 9. Split email body into a list of words
email_body_split = emails["Email 9"]["body"].split()
print(email_body_split)

# 10. Join list of words into a single sentence
email_words = emails["Email 10"]["body"].split()
email_sentence = " ".join(email_words)
print(email_sentence)
# Out:
# Hello, John Doe! Your account has been activated.
# MEETING REMINDER
# please review the attached document.
# This email needs to be capitalized.
# Weekly Update
# Thank you for your feedback. Please respond at your earliest convenience.
# The system encountered an error that needs to be addressed.
# 25
# ['Split', 'this', 'email', 'into', 'individual', 'words.']
# join these words into a single sentence
